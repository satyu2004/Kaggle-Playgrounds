# %%
import pandas as pd
test_path = 'test.csv'
df = pd.read_csv(test_path)

# %%
df['Number_of_Ads'].value_counts()
# Out:
# Number_of_Ads
# 0.00       72863
# 1.00       71015
# 3.00       53556
# 2.00       52564
# 89.12          1
# 2063.00        1
# Name: count, dtype: int64

# %%
(df['Episode_Length_minutes']>1000).sum()
# Out:
# np.int64(2)

# %%
df['Episode_Length_minutes'][df['Episode_Length_minutes']<1000].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Host_Popularity_percentage'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Guest_Popularity_percentage'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.describe(include='all')
# Out:
#                    id Podcast_Name Episode_Title  Episode_Length_minutes  \
# count   250000.000000       250000        250000            2.212640e+05
# unique            NaN           48           100                     NaN
# top               NaN   Tech Talks    Episode 71                     NaN
# freq              NaN         7553          3492                     NaN
# mean    874999.500000          NaN           NaN            4.192987e+02
# std      72168.927986          NaN           NaN            1.668545e+05
# min     750000.000000          NaN           NaN            2.470000e+00
# 25%     812499.750000          NaN           NaN            3.578000e+01
# 50%     874999.500000          NaN           NaN            6.397000e+01
# 75%     937499.250000          NaN           NaN            9.415000e+01
# max     999999.000000          NaN           NaN            7.848626e+07
#
#          Genre  Host_Popularity_percentage Publication_Day Publication_Time  \
# ...

# %%
df['Podcast_Name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Podcast_Name'>

# %%
df['Genre'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Genre'>

# %%
df['Publication_Day'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Publication_Day'>

# %%
df['Publication_Time'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Publication_Time'>

# %%
df['Number_of_Ads'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Number_of_Ads'>

# %%
df['Episode_Sentiment'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Episode_Sentiment'>
